# %% [markdown]
# <h1>Lab Assignment 1</h1>
# <p>Date: 24-Aug-22 <br> Dataset: Iris Flower</p>

# %%
import pandas as pd

# %%
df = pd.read_csv("IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.0          3.0           1.5          0.2      Iris-setosa
# 1           NaN          NaN           NaN          NaN  Iris-versicolor
# 2           NaN          NaN           NaN          NaN   Iris-virginica

# %%
# Range of sepal length
df.max().sepal_length - df.min().sepal_length
# Out:
# 3.6000000000000005

# %%
# Range of sepal width
df.max().sepal_width - df.min().sepal_width
# Out:
# 2.4000000000000004

# %%
# Range of petal length
df.max().petal_length - df.min().petal_length
# Out:
# 5.9

# %%
# Range of petal width
df.max().petal_width - df.min().petal_width
# Out:
# 2.4

# %%
# Standard deviation (or σ): a measure of how dispersed the data is in relation to the mean
# Low standard deviation: data are clustered around the mean
# High standard deviation: data are more spread out
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
# sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %%
# Variance: the degree of spread in a data set about the mean value of that data
# It shows the amount of variation that exists among the data points
df.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# sepal_length    0.685694
# sepal_width     0.188004
# petal_length    3.113179
# petal_width     0.582414
# dtype: float64

# %%
# Skewness: a measure of asymmetry or distortion of symmetric distribution
# Right (or Positive) Skew: longer on the right side of its peak than on its left
# Left (or Negative) Skew: longer on the left side of its peak than on its right
# Zero Skew: symmetrical
df.skew()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """
# sepal_length    0.314911
# sepal_width     0.334053
# petal_length   -0.274464
# petal_width    -0.104997
# dtype: float64

# %% [markdown]
# ![sk1.webp](data:image/webp;base64,...)

# %%
# Interquartile range: the range of values that resides in the middle of the scores
# The best measure of variability for skewed distributions or data sets with outliers
q1 = df.median()/2
q3 = q1*3
print(q3 - q1)
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe().iat[5,0]
# Out:
# 5.8

# %% [markdown]
# <h1>Lab Assignment 2</h1>
# <h5>Date: 31-Aug-22 <br> Data Visualization</h5>

# %% [markdown]
# - co-relation b/w two variable: Scatter plot
# - Pair-wise plot
# - frequency of species: Bar graph, pie chart, donut chart
# - Class balanced: all species/class has same frequency
# - Count frequency of each species
# - Finding Outlier? Box plot

# %%
# SCATTER PLOT: A Scatter plot is a type of data visualization technique that shows the relationship between two numerical variables.
df.plot.scatter(x = 'sepal_length', y = 'sepal_width', s = 50, c = 'purple')

# %%
df.plot.scatter(x = 'petal_length', y = 'petal_width', s = 50, c = 'purple')

# %%
# PAIRPLOT: To plot multiple pairwise bivariate distributions in a dataset
import matplotlib.pyplot as plt
import seaborn
seaborn.pairplot(df, hue = 'species')
plt.show()

# %%
group = df.groupby("species")
plt.bar(x = 'species', group.count(), color = 'indigo', width = 0.3)
# joint plot
# Out:
#   File "<ipython-input-70-00c3f51e84af>", line 2
#     plt.bar(x = 'species', group.count(), color = 'indigo', width = 0.3)
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
seaborn.boxplot(x = 'species', y = 'sepal_length', data = df, hue = 'species')

# %%
df.boxplot(by = 'species', figsize = (10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb8f74151d0>,
# ...
#       dtype=object)
